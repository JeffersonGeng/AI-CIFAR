# %%
# Ce code "TP_CNN_TSP"est basé sur tensorflow et keras pour construire un modele CNN
# Ce code est basé sur le tutorial de CNN-tensorflow https://www.tensorflow.org/tutorials/images/cnn
#Pour lier google Colab avec google drive

# %%
# Pour importer les outils 
from __future__ import absolute_import, division, print_function, unicode_literals

try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf

from tensorflow.keras import datasets, layers, models, Model
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import numpy as np
import cv2
from matplotlib import pyplot
import h5py
from tensorflow.keras.utils import img_to_array
import tensorflow.keras as keras
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Pour telécharger la database
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
#Pour afficher 25 images de l'ensemble d'apprentissage
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %%
# Taper les lignes nécessaires pour définir le modele CNN. C'est à vous d'essayer ;)
def create_model():
    model = models.Sequential()
    # Une convolution de 32 filtres en 3×3 suivie d’une couche d’activation ReLU
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
    # Un max pooling de 2×2
    model.add(layers.MaxPooling2D((2, 2)))
    # Une convolution de 64 filtres en 3×3 suivie d’une couche d’activation ReLU
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    # Un max pooling de 2×2
    model.add(layers.MaxPooling2D((2, 2)))
    # Une convolution de 64 filtres en 3×3 suivie d’une couche d’activation ReLU
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    # Un flatten
    model.add(layers.Flatten())
    # Un dense à 64 sorties avec un ReLU
    model.add(layers.Dense(64, activation='relu'))
    # Un dense final à 10 sorties avec un softmax
    model.add(layers.Dense(10, activation='softmax'))
    return model

model = create_model()
print('Model created')
# Out:
# /home/jeff/TP-CNN/tp-cnn/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1741677114.307942  140405 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7764 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model created

# %%
#Pour afficher l'architecture du modele CNN
model.summary()
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True, expand_nested=True, rankdir='TB')
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 4, 4, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        65,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 122,570 (478.79 KB)
#  Trainable params: 122,570 (478.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Pour compilation et entrainement
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=200, 
                    validation_data=(test_images, test_labels))
#keras.models.save_model(model, 'TP_CNN_TSP.keras')
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741677121.818582  144161 service.cc:148] XLA service 0x7fdebc004f60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1741677121.818611  144161 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 3080 Ti, Compute Capability 8.6
# 2025-03-11 08:12:01.833718: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1741677121.909028  144161 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   92/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1326 - loss: 2.2752
# I0000 00:00:1741677123.609410  144161 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.3504 - loss: 1.7513 - val_accuracy: 0.5634 - val_loss: 1.2116
# Epoch 2/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.5854 - loss: 1.1655 - val_accuracy: 0.6270 - val_loss: 1.0567
# Epoch 3/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6503 - loss: 0.9994 - val_accuracy: 0.6559 - val_loss: 0.9771
# Epoch 4/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.6896 - loss: 0.8886 - val_accuracy: 0.6784 - val_loss: 0.9234
# Epoch 5/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7121 - loss: 0.8121 - val_accuracy: 0.6802 - val_loss: 0.9152
# Epoch 6/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7356 - loss: 0.7545 - val_accuracy: 0.7111 - val_loss: 0.8324
# Epoch 7/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7548 - loss: 0.7023 - val_accuracy: 0.6988 - val_loss: 0.8867
# Epoch 8/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7685 - loss: 0.6560 - val_accuracy: 0.7107 - val_loss: 0.8621
# Epoch 9/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7828 - loss: 0.6157 - val_accuracy: 0.6976 - val_loss: 0.9015
# Epoch 10/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7941 - loss: 0.5772 - val_accuracy: 0.7050 - val_loss: 0.8874
# Epoch 11/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8074 - loss: 0.5421 - val_accuracy: 0.7225 - val_loss: 0.8445
# Epoch 12/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8206 - loss: 0.5075 - val_accuracy: 0.7128 - val_loss: 0.9159
# Epoch 13/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8329 - loss: 0.4711 - val_accuracy: 0.7089 - val_loss: 0.9331
# Epoch 14/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8421 - loss: 0.4463 - val_accuracy: 0.7033 - val_loss: 0.9954
# Epoch 15/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8510 - loss: 0.4181 - val_accuracy: 0.7050 - val_loss: 1.0174
# Epoch 16/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8631 - loss: 0.3923 - val_accuracy: 0.7129 - val_loss: 1.0018
# Epoch 17/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8713 - loss: 0.3649 - val_accuracy: 0.7084 - val_loss: 1.0789
# Epoch 18/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8786 - loss: 0.3403 - val_accuracy: 0.7058 - val_loss: 1.1132
# Epoch 19/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8867 - loss: 0.3179 - val_accuracy: 0.7037 - val_loss: 1.1421
# Epoch 20/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8932 - loss: 0.2970 - val_accuracy: 0.6933 - val_loss: 1.2309
# Epoch 21/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8946 - loss: 0.2952 - val_accuracy: 0.6921 - val_loss: 1.2990
# Epoch 22/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9026 - loss: 0.2704 - val_accuracy: 0.7025 - val_loss: 1.2946
# Epoch 23/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9085 - loss: 0.2500 - val_accuracy: 0.7020 - val_loss: 1.2799
# Epoch 24/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9170 - loss: 0.2307 - val_accuracy: 0.6911 - val_loss: 1.5023
# Epoch 25/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9212 - loss: 0.2204 - val_accuracy: 0.6988 - val_loss: 1.4742
# Epoch 26/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9226 - loss: 0.2133 - val_accuracy: 0.6939 - val_loss: 1.5213
# Epoch 27/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9253 - loss: 0.2024 - val_accuracy: 0.6932 - val_loss: 1.5487
# Epoch 28/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9322 - loss: 0.1873 - val_accuracy: 0.6887 - val_loss: 1.6555
# Epoch 29/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9380 - loss: 0.1785 - val_accuracy: 0.6958 - val_loss: 1.7005
# Epoch 30/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9412 - loss: 0.1605 - val_accuracy: 0.6894 - val_loss: 1.7871
# Epoch 31/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9416 - loss: 0.1653 - val_accuracy: 0.6855 - val_loss: 1.7056
# Epoch 32/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9453 - loss: 0.1491 - val_accuracy: 0.6909 - val_loss: 1.8432
# Epoch 33/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9435 - loss: 0.1556 - val_accuracy: 0.6833 - val_loss: 1.9133
# Epoch 34/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9483 - loss: 0.1452 - val_accuracy: 0.6867 - val_loss: 1.9668
# Epoch 35/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9441 - loss: 0.1566 - val_accuracy: 0.6883 - val_loss: 1.9983
# Epoch 36/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9478 - loss: 0.1424 - val_accuracy: 0.6863 - val_loss: 2.0429
# Epoch 37/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9518 - loss: 0.1326 - val_accuracy: 0.6899 - val_loss: 2.0609
# Epoch 38/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9554 - loss: 0.1244 - val_accuracy: 0.6817 - val_loss: 2.1241
# Epoch 39/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9510 - loss: 0.1388 - val_accuracy: 0.6806 - val_loss: 2.2367
# Epoch 40/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9510 - loss: 0.1334 - val_accuracy: 0.6843 - val_loss: 2.2239
# Epoch 41/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9584 - loss: 0.1196 - val_accuracy: 0.6762 - val_loss: 2.3475
# Epoch 42/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9589 - loss: 0.1183 - val_accuracy: 0.6870 - val_loss: 2.3161
# Epoch 43/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9581 - loss: 0.1199 - val_accuracy: 0.6812 - val_loss: 2.3440
# Epoch 44/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9583 - loss: 0.1194 - val_accuracy: 0.6876 - val_loss: 2.3309
# Epoch 45/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9593 - loss: 0.1146 - val_accuracy: 0.6887 - val_loss: 2.4081
# Epoch 46/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9635 - loss: 0.1003 - val_accuracy: 0.6833 - val_loss: 2.3998
# Epoch 47/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9649 - loss: 0.0974 - val_accuracy: 0.6888 - val_loss: 2.4927
# Epoch 48/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9589 - loss: 0.1223 - val_accuracy: 0.6940 - val_loss: 2.4945
# Epoch 49/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9638 - loss: 0.1040 - val_accuracy: 0.6844 - val_loss: 2.4532
# Epoch 50/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9687 - loss: 0.0891 - val_accuracy: 0.6778 - val_loss: 2.5771
# Epoch 51/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9645 - loss: 0.1033 - val_accuracy: 0.6831 - val_loss: 2.5163
# Epoch 52/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9664 - loss: 0.0984 - val_accuracy: 0.6860 - val_loss: 2.5687
# Epoch 53/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9675 - loss: 0.0943 - val_accuracy: 0.6809 - val_loss: 2.6083
# Epoch 54/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9663 - loss: 0.0997 - val_accuracy: 0.6855 - val_loss: 2.6521
# Epoch 55/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9688 - loss: 0.0922 - val_accuracy: 0.6838 - val_loss: 2.6814
# Epoch 56/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9706 - loss: 0.0912 - val_accuracy: 0.6788 - val_loss: 2.6226
# Epoch 57/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9659 - loss: 0.1020 - val_accuracy: 0.6906 - val_loss: 2.7726
# Epoch 58/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9688 - loss: 0.0931 - val_accuracy: 0.6800 - val_loss: 2.7625
# Epoch 59/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9686 - loss: 0.0893 - val_accuracy: 0.6784 - val_loss: 2.8330
# Epoch 60/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9667 - loss: 0.0954 - val_accuracy: 0.6796 - val_loss: 2.8076
# Epoch 61/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9740 - loss: 0.0764 - val_accuracy: 0.6769 - val_loss: 2.9073
# Epoch 62/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9653 - loss: 0.1029 - val_accuracy: 0.6874 - val_loss: 2.8669
# Epoch 63/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9672 - loss: 0.0941 - val_accuracy: 0.6849 - val_loss: 2.9894
# Epoch 64/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9701 - loss: 0.0868 - val_accuracy: 0.6781 - val_loss: 3.0350
# Epoch 65/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9716 - loss: 0.0852 - val_accuracy: 0.6729 - val_loss: 2.9906
# Epoch 66/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9730 - loss: 0.0824 - val_accuracy: 0.6758 - val_loss: 3.0514
# Epoch 67/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9694 - loss: 0.0921 - val_accuracy: 0.6812 - val_loss: 2.9962
# Epoch 68/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9743 - loss: 0.0787 - val_accuracy: 0.6777 - val_loss: 3.0815
# Epoch 69/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9726 - loss: 0.0806 - val_accuracy: 0.6804 - val_loss: 3.0443
# Epoch 70/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9666 - loss: 0.1040 - val_accuracy: 0.6703 - val_loss: 3.1215
# Epoch 71/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9722 - loss: 0.0847 - val_accuracy: 0.6762 - val_loss: 3.1024
# Epoch 72/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9712 - loss: 0.0892 - val_accuracy: 0.6815 - val_loss: 3.0735
# Epoch 73/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9748 - loss: 0.0755 - val_accuracy: 0.6761 - val_loss: 3.1326
# Epoch 74/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9736 - loss: 0.0797 - val_accuracy: 0.6784 - val_loss: 3.2280
# Epoch 75/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9717 - loss: 0.0864 - val_accuracy: 0.6841 - val_loss: 3.0519
# Epoch 76/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9746 - loss: 0.0770 - val_accuracy: 0.6756 - val_loss: 3.1438
# Epoch 77/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9750 - loss: 0.0743 - val_accuracy: 0.6752 - val_loss: 3.1958
# Epoch 78/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9749 - loss: 0.0777 - val_accuracy: 0.6698 - val_loss: 3.3088
# Epoch 79/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9749 - loss: 0.0737 - val_accuracy: 0.6793 - val_loss: 3.1715
# Epoch 80/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9750 - loss: 0.0744 - val_accuracy: 0.6781 - val_loss: 3.2270
# Epoch 81/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9776 - loss: 0.0683 - val_accuracy: 0.6819 - val_loss: 3.3525
# Epoch 82/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9738 - loss: 0.0814 - val_accuracy: 0.6706 - val_loss: 3.4736
# Epoch 83/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9751 - loss: 0.0753 - val_accuracy: 0.6771 - val_loss: 3.4578
# Epoch 84/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9760 - loss: 0.0742 - val_accuracy: 0.6714 - val_loss: 3.4809
# Epoch 85/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9732 - loss: 0.0833 - val_accuracy: 0.6851 - val_loss: 3.2980
# Epoch 86/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9777 - loss: 0.0680 - val_accuracy: 0.6746 - val_loss: 3.3424
# Epoch 87/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9786 - loss: 0.0662 - val_accuracy: 0.6817 - val_loss: 3.4286
# Epoch 88/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9775 - loss: 0.0689 - val_accuracy: 0.6781 - val_loss: 3.4683
# Epoch 89/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9729 - loss: 0.0863 - val_accuracy: 0.6769 - val_loss: 3.5035
# Epoch 90/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9796 - loss: 0.0668 - val_accuracy: 0.6784 - val_loss: 3.4765
# Epoch 91/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9753 - loss: 0.0783 - val_accuracy: 0.6810 - val_loss: 3.3844
# Epoch 92/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9763 - loss: 0.0726 - val_accuracy: 0.6778 - val_loss: 3.5027
# Epoch 93/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9766 - loss: 0.0704 - val_accuracy: 0.6762 - val_loss: 3.6079
# Epoch 94/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9777 - loss: 0.0682 - val_accuracy: 0.6736 - val_loss: 3.6186
# Epoch 95/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9785 - loss: 0.0655 - val_accuracy: 0.6799 - val_loss: 3.5481
# Epoch 96/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9775 - loss: 0.0702 - val_accuracy: 0.6757 - val_loss: 3.6683
# Epoch 97/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9749 - loss: 0.0790 - val_accuracy: 0.6781 - val_loss: 3.7180
# Epoch 98/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9788 - loss: 0.0680 - val_accuracy: 0.6743 - val_loss: 3.7041
# Epoch 99/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9733 - loss: 0.0853 - val_accuracy: 0.6804 - val_loss: 3.5383
# Epoch 100/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9780 - loss: 0.0687 - val_accuracy: 0.6783 - val_loss: 3.6279
# Epoch 101/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9801 - loss: 0.0600 - val_accuracy: 0.6769 - val_loss: 3.7464
# Epoch 102/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9790 - loss: 0.0657 - val_accuracy: 0.6764 - val_loss: 3.7610
# Epoch 103/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9779 - loss: 0.0709 - val_accuracy: 0.6758 - val_loss: 3.7287
# Epoch 104/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9762 - loss: 0.0730 - val_accuracy: 0.6733 - val_loss: 3.9100
# Epoch 105/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9764 - loss: 0.0819 - val_accuracy: 0.6776 - val_loss: 3.7706
# Epoch 106/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9785 - loss: 0.0647 - val_accuracy: 0.6777 - val_loss: 3.9237
# Epoch 107/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9773 - loss: 0.0734 - val_accuracy: 0.6739 - val_loss: 3.8313
# Epoch 108/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9791 - loss: 0.0664 - val_accuracy: 0.6810 - val_loss: 3.6683
# Epoch 109/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9783 - loss: 0.0688 - val_accuracy: 0.6790 - val_loss: 3.6918
# Epoch 110/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9785 - loss: 0.0666 - val_accuracy: 0.6795 - val_loss: 3.7502
# Epoch 111/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9795 - loss: 0.0655 - val_accuracy: 0.6798 - val_loss: 3.8450
# Epoch 112/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9769 - loss: 0.0733 - val_accuracy: 0.6856 - val_loss: 3.9585
# Epoch 113/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9817 - loss: 0.0565 - val_accuracy: 0.6710 - val_loss: 4.0598
# Epoch 114/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9797 - loss: 0.0634 - val_accuracy: 0.6787 - val_loss: 3.9797
# Epoch 115/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9769 - loss: 0.0737 - val_accuracy: 0.6758 - val_loss: 4.0059
# Epoch 116/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9823 - loss: 0.0545 - val_accuracy: 0.6793 - val_loss: 3.9767
# Epoch 117/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9802 - loss: 0.0632 - val_accuracy: 0.6771 - val_loss: 4.0976
# Epoch 118/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9762 - loss: 0.0781 - val_accuracy: 0.6801 - val_loss: 3.9040
# Epoch 119/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9816 - loss: 0.0600 - val_accuracy: 0.6793 - val_loss: 3.9932
# Epoch 120/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9802 - loss: 0.0622 - val_accuracy: 0.6714 - val_loss: 4.1561
# Epoch 121/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9776 - loss: 0.0732 - val_accuracy: 0.6832 - val_loss: 3.9236
# Epoch 122/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9790 - loss: 0.0704 - val_accuracy: 0.6743 - val_loss: 3.9964
# Epoch 123/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9839 - loss: 0.0551 - val_accuracy: 0.6788 - val_loss: 3.9874
# Epoch 124/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9795 - loss: 0.0688 - val_accuracy: 0.6801 - val_loss: 4.2045
# Epoch 125/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9803 - loss: 0.0641 - val_accuracy: 0.6796 - val_loss: 4.1436
# Epoch 126/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9802 - loss: 0.0648 - val_accuracy: 0.6808 - val_loss: 4.2170
# Epoch 127/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9819 - loss: 0.0582 - val_accuracy: 0.6831 - val_loss: 4.2494
# Epoch 128/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9811 - loss: 0.0624 - val_accuracy: 0.6771 - val_loss: 4.1329
# Epoch 129/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9786 - loss: 0.0709 - val_accuracy: 0.6753 - val_loss: 4.2163
# Epoch 130/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9795 - loss: 0.0703 - val_accuracy: 0.6825 - val_loss: 4.1593
# Epoch 131/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9821 - loss: 0.0600 - val_accuracy: 0.6758 - val_loss: 4.2697
# Epoch 132/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9790 - loss: 0.0709 - val_accuracy: 0.6747 - val_loss: 4.4094
# Epoch 133/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9804 - loss: 0.0669 - val_accuracy: 0.6765 - val_loss: 4.3507
# Epoch 134/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9806 - loss: 0.0668 - val_accuracy: 0.6780 - val_loss: 4.1643
# Epoch 135/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9810 - loss: 0.0648 - val_accuracy: 0.6792 - val_loss: 4.3463
# Epoch 136/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9836 - loss: 0.0555 - val_accuracy: 0.6752 - val_loss: 4.3382
# Epoch 137/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9812 - loss: 0.0650 - val_accuracy: 0.6739 - val_loss: 4.4275
# Epoch 138/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9784 - loss: 0.0718 - val_accuracy: 0.6749 - val_loss: 4.5164
# Epoch 139/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9776 - loss: 0.0803 - val_accuracy: 0.6781 - val_loss: 4.4288
# Epoch 140/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9835 - loss: 0.0601 - val_accuracy: 0.6749 - val_loss: 4.4534
# Epoch 141/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9792 - loss: 0.0711 - val_accuracy: 0.6675 - val_loss: 4.5718
# Epoch 142/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9800 - loss: 0.0682 - val_accuracy: 0.6741 - val_loss: 4.5155
# Epoch 143/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9826 - loss: 0.0601 - val_accuracy: 0.6819 - val_loss: 4.5593
# Epoch 144/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9794 - loss: 0.0684 - val_accuracy: 0.6759 - val_loss: 4.5734
# Epoch 145/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9828 - loss: 0.0589 - val_accuracy: 0.6758 - val_loss: 4.5154
# Epoch 146/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9787 - loss: 0.0776 - val_accuracy: 0.6778 - val_loss: 4.4514
# Epoch 147/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9851 - loss: 0.0478 - val_accuracy: 0.6815 - val_loss: 4.5072
# Epoch 148/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9795 - loss: 0.0756 - val_accuracy: 0.6824 - val_loss: 4.6113
# Epoch 149/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9834 - loss: 0.0582 - val_accuracy: 0.6755 - val_loss: 4.6580
# Epoch 150/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9817 - loss: 0.0649 - val_accuracy: 0.6729 - val_loss: 4.7106
# Epoch 151/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9811 - loss: 0.0688 - val_accuracy: 0.6710 - val_loss: 4.6314
# Epoch 152/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9801 - loss: 0.0729 - val_accuracy: 0.6661 - val_loss: 4.6886
# Epoch 153/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9806 - loss: 0.0708 - val_accuracy: 0.6738 - val_loss: 4.6892
# Epoch 154/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9830 - loss: 0.0621 - val_accuracy: 0.6758 - val_loss: 4.6429
# Epoch 155/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9811 - loss: 0.0625 - val_accuracy: 0.6683 - val_loss: 4.7268
# Epoch 156/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9797 - loss: 0.0743 - val_accuracy: 0.6730 - val_loss: 4.8948
# Epoch 157/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9809 - loss: 0.0680 - val_accuracy: 0.6751 - val_loss: 4.6853
# Epoch 158/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9832 - loss: 0.0541 - val_accuracy: 0.6741 - val_loss: 4.7321
# Epoch 159/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9829 - loss: 0.0595 - val_accuracy: 0.6683 - val_loss: 4.7172
# Epoch 160/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9835 - loss: 0.0527 - val_accuracy: 0.6720 - val_loss: 4.9847
# Epoch 161/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9813 - loss: 0.0656 - val_accuracy: 0.6747 - val_loss: 4.7732
# Epoch 162/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9837 - loss: 0.0595 - val_accuracy: 0.6722 - val_loss: 5.1071
# Epoch 163/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9809 - loss: 0.0696 - val_accuracy: 0.6729 - val_loss: 4.9375
# Epoch 164/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9828 - loss: 0.0607 - val_accuracy: 0.6771 - val_loss: 4.9603
# Epoch 165/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9807 - loss: 0.0695 - val_accuracy: 0.6713 - val_loss: 5.1165
# Epoch 166/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9834 - loss: 0.0609 - val_accuracy: 0.6755 - val_loss: 5.1467
# Epoch 167/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9835 - loss: 0.0607 - val_accuracy: 0.6770 - val_loss: 5.2287
# Epoch 168/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9823 - loss: 0.0676 - val_accuracy: 0.6724 - val_loss: 5.0932
# Epoch 169/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9808 - loss: 0.0695 - val_accuracy: 0.6741 - val_loss: 5.0266
# Epoch 170/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9814 - loss: 0.0661 - val_accuracy: 0.6765 - val_loss: 5.2311
# Epoch 171/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9815 - loss: 0.0675 - val_accuracy: 0.6784 - val_loss: 5.2104
# Epoch 172/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9804 - loss: 0.0728 - val_accuracy: 0.6733 - val_loss: 5.0494
# Epoch 173/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9843 - loss: 0.0540 - val_accuracy: 0.6718 - val_loss: 5.3410
# Epoch 174/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9832 - loss: 0.0670 - val_accuracy: 0.6756 - val_loss: 5.1427
# Epoch 175/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9831 - loss: 0.0621 - val_accuracy: 0.6722 - val_loss: 5.2190
# Epoch 176/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9801 - loss: 0.0748 - val_accuracy: 0.6756 - val_loss: 5.1306
# Epoch 177/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9841 - loss: 0.0634 - val_accuracy: 0.6694 - val_loss: 5.3793
# Epoch 178/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9804 - loss: 0.0751 - val_accuracy: 0.6768 - val_loss: 5.3683
# Epoch 179/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9860 - loss: 0.0532 - val_accuracy: 0.6659 - val_loss: 5.4604
# Epoch 180/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9781 - loss: 0.0825 - val_accuracy: 0.6767 - val_loss: 5.4301
# Epoch 181/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9828 - loss: 0.0669 - val_accuracy: 0.6792 - val_loss: 5.5070
# Epoch 182/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9820 - loss: 0.0676 - val_accuracy: 0.6763 - val_loss: 5.5888
# Epoch 183/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9823 - loss: 0.0676 - val_accuracy: 0.6738 - val_loss: 5.4500
# Epoch 184/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9840 - loss: 0.0631 - val_accuracy: 0.6772 - val_loss: 5.2521
# Epoch 185/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9828 - loss: 0.0692 - val_accuracy: 0.6743 - val_loss: 5.4165
# Epoch 186/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9825 - loss: 0.0670 - val_accuracy: 0.6758 - val_loss: 5.3751
# Epoch 187/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9802 - loss: 0.0755 - val_accuracy: 0.6714 - val_loss: 5.5978
# Epoch 188/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9844 - loss: 0.0590 - val_accuracy: 0.6724 - val_loss: 5.7090
# Epoch 189/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9770 - loss: 0.0963 - val_accuracy: 0.6790 - val_loss: 5.4904
# Epoch 190/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9852 - loss: 0.0550 - val_accuracy: 0.6801 - val_loss: 5.4294
# Epoch 191/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9833 - loss: 0.0606 - val_accuracy: 0.6642 - val_loss: 5.6545
# Epoch 192/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9805 - loss: 0.0785 - val_accuracy: 0.6742 - val_loss: 5.7595
# Epoch 193/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9850 - loss: 0.0564 - val_accuracy: 0.6788 - val_loss: 5.5212
# Epoch 194/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9850 - loss: 0.0553 - val_accuracy: 0.6773 - val_loss: 5.4568
# Epoch 195/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9831 - loss: 0.0698 - val_accuracy: 0.6707 - val_loss: 5.7277
# Epoch 196/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9838 - loss: 0.0600 - val_accuracy: 0.6736 - val_loss: 5.8837
# Epoch 197/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9811 - loss: 0.0766 - val_accuracy: 0.6798 - val_loss: 5.7824
# Epoch 198/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9830 - loss: 0.0666 - val_accuracy: 0.6812 - val_loss: 5.6775
# Epoch 199/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9837 - loss: 0.0650 - val_accuracy: 0.6739 - val_loss: 5.8173
# Epoch 200/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9815 - loss: 0.0741 - val_accuracy: 0.6727 - val_loss: 6.0679

# %%
# Pour tracer la courbe accuracy en foctions de nombre des epochs
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
# plt.ylim([0.5, 1])
plt.legend(loc='lower right')
plt.show()
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
# plt.ylim([0.5, 1])
plt.legend(loc='lower right')
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
best_val_acc = max(history.history['val_accuracy'])
best_acc = max(history.history['accuracy'])
best_loss = min(history.history['loss'])
best_val_loss = min(history.history['val_loss'])
print(f'best_acc: {100*best_acc:.2f}%')
print(f'best_val_acc: {100*best_val_acc:.2f}%')
print(f'best_loss: {best_loss:.5f}')
print(f'best_val_loss: {best_val_loss:.5f}')
#Pour tester le modele
print(f'test_acc: {100*test_acc:.2f}%')
print(f'test_loss: {test_loss:.5f}')
# Out:
# 313/313 - 0s - 2ms/step - accuracy: 0.6727 - loss: 6.0679
# best_acc: 98.35%
# best_val_acc: 72.25%
# best_loss: 0.05855
# best_val_loss: 0.83243
# test_acc: 67.27%
# test_loss: 6.06786

# %%
#pour importer l'image chien.jpg
img = cv2.imread("chien.jpg")
img_cvt=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)
plt.show()

# %%
#Pour la prédiction de l'image chien
img = cv2.resize(img_cvt, (32,32))
img = img.astype('float32')
img= img / 255.0
imgs = tf.expand_dims(
    img,
    axis=0,
    name=None
)
model.predict(imgs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# array([[6.0003600e-42, 3.3989387e-28, 2.2451736e-09, 2.1762800e-05,
#         7.9801377e-21, 9.9997818e-01, 2.3907076e-10, 8.1224511e-38,
#         2.6314670e-38, 4.7942471e-33]], dtype=float32)

# %%
#pour visualiser la couche i

for i in range(5):
	# summarize output shape
	print(i, model.layers[i].name, model.layers[i].output.shape)
	# define a new model that outputs the layer
	model2 = Model(inputs=model.inputs, outputs=model.layers[i].output)
	model2.summary()
	feature_maps = model2.predict(imgs)
	square = 5
	ix = 1
	for _ in range(square):
		for _ in range(square):
			# specify subplot and turn of axis
			ax = pyplot.subplot(square, square, ix)
			ax.set_xticks([])
			ax.set_yticks([])
			# plot filter channel in grayscale
			pyplot.imshow(feature_maps[0, :, :, ix-1])
			ix += 1
	# show the figure
	pyplot.show()
# Out:
# 0 conv2d (None, 30, 30, 32)
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 896 (3.50 KB)
#  Trainable params: 896 (3.50 KB)
#  Non-trainable params: 0 (0.00 B)
# /home/jeff/TP-CNN/tp-cnn/lib/python3.12/site-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(1, 32, 32, 3))
#   warnings.warn(msg)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1 max_pooling2d (None, 15, 15, 32)
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 896 (3.50 KB)
#  Trainable params: 896 (3.50 KB)
#  Non-trainable params: 0 (0.00 B)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 2 conv2d_1 (None, 13, 13, 64)
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,392 (75.75 KB)
#  Trainable params: 19,392 (75.75 KB)
#  Non-trainable params: 0 (0.00 B)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 3 max_pooling2d_1 (None, 6, 6, 64)
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,392 (75.75 KB)
#  Trainable params: 19,392 (75.75 KB)
#  Non-trainable params: 0 (0.00 B)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fdf3c47eca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 4 conv2d_2 (None, 4, 4, 64)
# Model: "functional_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 4, 4, 64)       │        36,928 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 56,320 (220.00 KB)
#  Trainable params: 56,320 (220.00 KB)
#  Non-trainable params: 0 (0.00 B)
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fdf28332ca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step

# %%
model2 = Model(inputs=model.inputs, outputs=model.layers[0].output)
feature_maps = model2.predict(imgs)
square = 6
ix = 1
for _ in range(4):
	for _ in range(8):
		# specify subplot and turn of axis
		ax = pyplot.subplot(4, 8, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		pyplot.imshow(feature_maps[0, :, :, ix-1])
		ix += 1
# show the figure
pyplot.savefig('cnn_layer_1.png')
pyplot.show()
model2 = Model(inputs=model.inputs, outputs=model.layers[1].output)
feature_maps = model2.predict(imgs)
square = 6
ix = 1
for _ in range(4):
	for _ in range(8):
		# specify subplot and turn of axis
		ax = pyplot.subplot(4, 8, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		pyplot.imshow(feature_maps[0, :, :, ix-1])
		ix += 1
# show the figure
pyplot.savefig('cnn_layer_2.png')
pyplot.show()
model2 = Model(inputs=model.inputs, outputs=model.layers[2].output)
feature_maps = model2.predict(imgs)
square = 8
ix = 1
for _ in range(square):
	for _ in range(square):
		# specify subplot and turn of axis
		ax = pyplot.subplot(square, square, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		pyplot.imshow(feature_maps[0, :, :, ix-1])
		ix += 1
# show the figure
pyplot.savefig('cnn_layer_3.png')
pyplot.show()
model2 = Model(inputs=model.inputs, outputs=model.layers[3].output)
feature_maps = model2.predict(imgs)
square = 8
ix = 1
for _ in range(square):
	for _ in range(square):
		# specify subplot and turn of axis
		ax = pyplot.subplot(square, square, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		pyplot.imshow(feature_maps[0, :, :, ix-1])
		ix += 1
# show the figure
pyplot.savefig('cnn_layer_4.png')
pyplot.show()
model2 = Model(inputs=model.inputs, outputs=model.layers[4].output)
feature_maps = model2.predict(imgs)
square = 8
ix = 1
for _ in range(square):
	for _ in range(square):
		# specify subplot and turn of axis
		ax = pyplot.subplot(square, square, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		pyplot.imshow(feature_maps[0, :, :, ix-1])
		ix += 1
# show the figure
pyplot.savefig('cnn_layer_5.png')
pyplot.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
